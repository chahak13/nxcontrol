# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
I_d = np.load('I_driver.npy')
I_h = np.load('I_hubs.npy')

# %%
plt.plot(I_d, 'k')
plt.plot(I_h, 'r')
plt.grid(True)

# %%
degree_driver = np.load('degree_driver.npy')
degree_hubs = np.load('degree_hubs.npy')

# %%
degree_driver.mean()
# Out:
# 2.438051913299438

# %%
degree_hubs.mean()
# Out:
# 127.27803050575328

# %%
_ = plt.hist(degree_driver, bins=200, density = True)
_ =plt.hist(degree_hubs, bins=800, density = True)

plt.xlim([0,200])
plt.ylim([0, 0.05])
# Out:
# (0, 0.05)
